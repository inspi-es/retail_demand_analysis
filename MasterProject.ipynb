# %% [markdown]
# <a href="https://colab.research.google.com/github/inspi-es/retail_demand_analysis/blob/main/MasterProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sqlalchemy import create_engine

# Your Postgres connection string
db_url = "postgresql+psycopg2://Test:bQNxVzJL4g6u@ep-noisy-flower-846766.us-east-2.aws.neon.tech/TravelTide?sslmode=require"

# Create connection
engine = create_engine(db_url)

# Example: check tables
tables = pd.read_sql("SELECT table_name FROM information_schema.tables WHERE table_schema='public'", engine)
print(tables)
# Out:
#   table_name
# 0   sessions
# 1    flights
# 2      users
# 3     hotels

# %%
tables = pd.read_sql("""
    SELECT table_name
    FROM information_schema.tables
    WHERE table_schema = 'public'
""", engine)

print(tables)
# Out:
#   table_name
# 0   sessions
# 1    flights
# 2      users
# 3     hotels

# %%
df = pd.read_sql("SELECT * FROM flights LIMIT 10", engine)
df.head()
# Out:
#                                    trip_id origin_airport destination  \
# 0  532825-0b2338063e474d82b357b701c7813a3e            YZD    montreal
# 1  532912-7032b35aa5c94d59bcd125eefe2a22ea            JFK     toronto
# 2  532926-dda789a5460f4a5da2ce457957be6e8b            DCA    new york
# 3  533002-d8bd62a2a688444fa0172d56643511c8            DCA     houston
# 4  533076-723e2f236c284704a35125cb4865e400            HNL      dallas
#
#   destination_airport  seats  return_flight_booked      departure_time  \
# 0                 YHU      1                  True 2023-03-15 08:00:00
# 1                 YKZ      1                  True 2023-03-14 12:00:00
# 2                 LGA      1                  True 2023-03-16 15:00:00
# 3                 HOU      1                  True 2023-03-13 09:00:00
# 4                 DAL      1                  True 2023-03-11 14:00:00
#
#           return_time  checked_bags        trip_airline  \
# 0 2023-03-18 08:00:00             2     United Airlines
# ...
